# %% [markdown]
# # Phase 4 Project: Time Series Modeling
#
# ##  Forecasting Real Estate Prices Using Time Series

# %% [markdown]
# * Student Name: Andrea Cabello

# %% [markdown]
# # Notebook 1: Obtaining, Cleaning, Scrubbing and Analyzing

# %% [markdown]
# ## I. Overview
#
# I have been hired by a real-estate investment firm to help them understand:
# - How real estate prices have changed overtime and,
# - How to use this information to invest in areas with the most potential value increase.
#
# To get me started I have been provided with a dataset from [Zillow Research](https://www.zillow.com/research/data/)
#
# ### Home values
#
# Zillow Home Value Index (ZHVI): A smoothed, seasonally adjusted measure of the typical home value and market changes across a given region and housing type. It reflects the typical value for homes in the 35th to 65th percentile range.
#
# ### Housing Bubble
#
# * On December 30, 2008, the [Case–Shiller home price index](https://en.wikipedia.org/wiki/Case%E2%80%93Shiller_index) reported its largest price drop in its history.
# * The credit crisis resulting from the bursting of the housing bubble is an important cause of the Great Recession in the United States.

# %% [markdown]
# ## II. Business Problem
#
# * What are the top 5 best zip codes for us to invest in?
#
#
# ### Preliminary List of questions:
# * What makes the value of a property go up?
# * Law of Supply and Demand.
# * Return On Investment
# * Average price over time
# * Jobs Market
# * Population growth
# * Access to the city center or other relevant landmarks
#
# Let's begin by defining best:
# * We will use 3 year (2015-2018) Return On Investment ratio to measure 'best'.
#
# After some preliminary analysis of the data, we have decided to make Connecticut our test state to optimize computational runtime.

# %% [markdown]
# ## III. Cleaning and Obtaining Data

# %%
import pandas as pd
from pandas import Series
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.io as pio

# %matplotlib inline

# %%
df = pd.read_csv('zillow_data.csv')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
print('Total Zipcodes in DataFrame:', len(df))
# Out:
# Total Zipcodes in DataFrame: 14723

# %% [markdown]
# ### Connecticut

# %% [markdown]
# * The firm is particularly interested in off-the-beaten-path areas of the North East Coast so I will focus my analysis on CT zipcodes.

# %%
## selecting ct zipcodes
df_ct = df.loc[df['State']== 'CT'].reset_index()
df_ct.drop(['index', 'RegionID', 'City', 'State', 'CountyName'], axis=1, inplace=True)
df_ct.rename(columns={'RegionName': 'Zipcode'}, inplace=True)

# %%
df_ct.Metro.unique()
# Out:
# array(['Hartford', 'New Haven', 'Stamford', 'New London', 'Torrington',
#        'Worcester'], dtype=object)

# %%
print(f'Number of CT zipcodes: {len(df_ct)}')
# Out:
# Number of CT zipcodes: 124

# %% [markdown]
# ### Obtaining ROIs

# %%
## 5 year ROI
df_ct['ROI_5yr'] = round((df_ct['2018-04'] - df_ct['2013-01'])/ df_ct['2013-01'],4)
## 3 year ROI
df_ct['ROI_3yr'] = round((df_ct['2018-04'] - df_ct['2015-01'])/ df_ct['2015-01'],4)

# %%
df_ct.info()
df_ct.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Columns: 270 entries, Zipcode to ROI_3yr
# dtypes: float64(221), int64(48), object(1)
# memory usage: 261.7+ KB
#    Zipcode      Metro  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# 0     6010   Hartford       113  120300.0  120000.0  119800.0  119400.0
# 1     6516  New Haven       417   96500.0   96300.0   96100.0   95900.0
# 2     6511  New Haven       546   89800.0   90000.0   90200.0   90300.0
# 3     6810   Stamford       685  151100.0  150700.0  150200.0  149700.0
# 4     6492  New Haven       899  146800.0  146600.0  146300.0  146100.0
#
#     1996-08   1996-09   1996-10  ...  2017-09  2017-10  2017-11  2017-12  \
# 0  119100.0  118800.0  118600.0  ...   191200   191800   192900   193600
# 1   95600.0   95300.0   95000.0  ...   177300   177800   178200   178700
# 2   90500.0   90700.0   90800.0  ...   187700   190100   193100   196300
# 3  149100.0  148600.0  148200.0  ...   258500   260900   262500   264000
# 4  145900.0  145700.0  145600.0  ...   250200   251700   253100   254500
#
#    2018-01  2018-02  2018-03  2018-04  ROI_5yr  ROI_3yr
# 0   194100   194900   195700   195700   0.1063   0.0982
# 1   179700   180200   179700   178700   0.0752   0.0970
# 2   198400   199100   199100   198300   0.1462   0.1839
# 3   265300   266100   266500   266500   0.2219   0.1839
# 4   256100   257600   257600   256400   0.1182   0.0410
#
# [5 rows x 270 columns]

# %% [markdown]
# ### Reshape from Wide to Long Format

# %%
def melt_data(df):
    melted = pd.melt(df, id_vars=['Zipcode', 'Metro', 'SizeRank', 'ROI_5yr', 'ROI_3yr'], 
                     var_name='Date')
    melted['Date'] = pd.to_datetime(melted['Date'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted

# %%
melted_df = melt_data(df_ct)

# %%
melted_df.isna().value_counts()
# Out:
# Zipcode  Metro  SizeRank  ROI_5yr  ROI_3yr  Date   value
# False    False  False     False    False    False  False    32860
# dtype: int64

# %%
#Change Zipcode dtype to 'str'
melted_df['Zipcode'] = melted_df['Zipcode'].astype(str)

# Make sure the data type of the 'Date' column is datetime
melted_df['Date'] = pd.to_datetime(melted_df['Date'], format='%m/%y')

# Set the 'Date' column as index
melted_df.set_index('Date', inplace=True)

# %%
melted_df.index
# Out:
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01',
#                ...
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Date', length=32860, freq=None)

# %% [markdown]
# * The data includes home values by month since April 1996 to April 2018.
# * Given the 2008 Housing Bubble precedent, I have decided to slice the dates and start my analysis at January 2008. This leaves us with a 10 year time window.

# %%
melted_df = melted_df['2008-01-01':'2018-04-01']

# %%
melted_df.resample('MS').mean().index
# Out:
# DatetimeIndex(['2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01',
#                '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01',
#                '2008-09-01', '2008-10-01',
#                ...
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Date', length=124, freq='MS')

# %%
melted_df.info()
melted_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15376 entries, 2008-01-01 to 2018-04-01
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Zipcode   15376 non-null  object
#  1   Metro     15376 non-null  object
#  2   SizeRank  15376 non-null  int64
#  3   ROI_5yr   15376 non-null  float64
#  4   ROI_3yr   15376 non-null  float64
#  5   value     15376 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 840.9+ KB
#            Zipcode      Metro  SizeRank  ROI_5yr  ROI_3yr     value
# Date
# 2008-01-01    6010   Hartford       113   0.1063   0.0982  219300.0
# 2008-01-01    6516  New Haven       417   0.0752   0.0970  223900.0
# 2008-01-01    6511  New Haven       546   0.1462   0.1839  243500.0
# 2008-01-01    6810   Stamford       685   0.2219   0.1839  321900.0
# 2008-01-01    6492  New Haven       899   0.1182   0.0410  280200.0

# %%
melted_df.tail()
# Out:
#            Zipcode       Metro  SizeRank  ROI_5yr  ROI_3yr     value
# Date
# 2018-04-01    6794  Torrington     14096   0.0378   0.0448  510500.0
# 2018-04-01    6793  Torrington     14356   0.2023   0.1628  664400.0
# 2018-04-01    6027    Hartford     14477   0.1301   0.0649  252700.0
# 2018-04-01    6796  Torrington     14552   0.1274   0.2028  418700.0
# 2018-04-01    6090    Hartford     14655   0.0770   0.0469  348200.0

# %% [markdown]
# ### IV. EDA

# %% [markdown]
# * ### Metro

# %%
metro_grp = melted_df.groupby('Metro')
metro_grp = metro_grp.value.mean()
metro_grp = metro_grp.sort_values(ascending=False).head(10)

# %%
metro_grp.plot.barh(color='pink')
plt.title('10-Year Mean Value by Metro')
plt.xlabel('Value in Millions of Dollars ($)')
plt.show()
plt.savefig('10yr-metro-mean-value')

# %% [markdown]
# Let's take a closer look into the top 3 with the highest mean value.

# %% [markdown]
#  * #### Stamford

# %%
stamford = melted_df.loc[melted_df['Metro']=='Stamford']
stamford.describe()
# Out:
#            SizeRank      ROI_5yr      ROI_3yr         value
# count   1984.000000  1984.000000  1984.000000  1.984000e+03
# mean    5395.500000     0.117881     0.068744  5.050442e+05
# std     2786.125208     0.108130     0.120613  3.820920e+05
# min      685.000000    -0.019200    -0.076400  1.185000e+05
# 25%     3724.750000     0.040875    -0.000250  2.750750e+05
# 50%     5896.500000     0.090450     0.030600  3.450000e+05
# 75%     6677.500000     0.155375     0.109650  7.189750e+05
# max    11245.000000     0.320200     0.316600  1.746000e+06

# %% [markdown]
#  * #### Torrington

# %%
torrington = melted_df.loc[melted_df['Metro']=='Torrington']
torrington.describe()
# Out:
#            SizeRank      ROI_5yr      ROI_3yr          value
# count   2480.000000  2480.000000  2480.000000    2480.000000
# mean   11759.300000     0.150080     0.112490  331128.870968
# std     2795.020029     0.099232     0.067996  123206.641312
# min     3789.000000     0.015000     0.021000  135800.000000
# 25%    10302.250000     0.077700     0.062300  245900.000000
# 50%    13041.500000     0.146900     0.090500  307450.000000
# 75%    13663.000000     0.190975     0.168325  409825.000000
# max    14552.000000     0.415800     0.248700  737800.000000

# %% [markdown]
#  * #### Hartford

# %%
hartford = melted_df.loc[melted_df['Metro']=='Hartford']
hartford.describe()
# Out:
#            SizeRank      ROI_5yr      ROI_3yr          value
# count   4340.000000  4340.000000  4340.000000    4340.000000
# mean    7921.885714     0.059234     0.071354  242469.493088
# std     3897.308858     0.046046     0.042045   65698.245634
# min      113.000000    -0.081200    -0.039600  103300.000000
# 25%     4011.000000     0.033900     0.040000  197475.000000
# 50%     8085.000000     0.063500     0.064900  242400.000000
# 75%    10809.000000     0.084400     0.096500  277900.000000
# max    14655.000000     0.155800     0.158000  460500.000000

# %% [markdown]
# * ### SizeRank

# %% [markdown]
# As per SizeRank values seen below, our data includes very densely populated, somewhat populated, and also some of the least populated zipcodes in the US.

# %%
melted_df.SizeRank.unique()
# Out:
# array([  113,   417,   546,   685,   899,  1145,  1332,  1362,  1599,
#         1901,  2093,  2192,  2301,  2390,  2497,  3051,  3245,  3281,
#         3368,  3532,  3565,  3581,  3696,  3760,  3778,  3789,  3978,
#         4011,  4230,  4324,  4531,  4587,  4674,  4717,  5580,  5624,
#         5687,  5756,  5852,  5870,  5941,  6037,  6063,  6084,  6176,
#         6270,  6288,  6329,  6424,  6591,  6599,  6813,  6913,  7022,
#         7031,  7144,  7259,  7317,  7382,  7471,  7496,  7595,  7704,
#         7741,  7890,  8085,  8368,  8425,  8427,  8584,  8601,  8943,
#         9032,  9136,  9160,  9275,  9298,  9457,  9577,  9681,  9715,
#         9788,  9871,  9903,  9977, 10164, 10281, 10446, 10463, 10591,
#        10651, 10663, 10786, 10809, 10893, 11245, 11629, 11907, 11929,
#        12034, 12184, 12310, 12406, 12469, 12556, 12817, 12967, 13018,
#        13065, 13214, 13215, 13266, 13465, 13564, 13567, 13646, 13714,
#        13908, 13927, 14096, 14356, 14477, 14552, 14655])

# %% [markdown]
# * ### Value

# %%
print('10 year average CT home value' ,round(melted_df['value'].mean(), 2))
# Out:
# 10 year average CT home value 280233.14

# %%
melted_df['value'].describe()
# Out:
# count    1.537600e+04
# mean     2.802331e+05
# std      1.840456e+05
# min      8.010000e+04
# 25%      1.838000e+05
# 50%      2.419000e+05
# 75%      3.145250e+05
# max      1.746000e+06
# Name: value, dtype: float64

# %%
monthly_data = melted_df.resample('MS').mean()['value']
monthly_data.plot()
plt.title('Typical Home Value by Month')
plt.ylabel('Value in US Dollars ($)')
plt.show()

# %% [markdown]
# Let's resample by year to see if we obtain a better visualization.

# %%
yearly_data = melted_df['value'].resample(rule='A').mean()
yearly_data.plot.line(color='magenta')
plt.title('Typical CT Home Value by Year')
plt.ylabel('Value in US Dollars ($)')
plt.savefig('typical-home-value-year')
plt.show()

# %% [markdown]
# * ### Zipcode

# %%
zipcode_grp = melted_df.groupby('Zipcode')

# %% [markdown]
# Up next, we'll plot our Top 10 Zipcodes with the highest mean value between 2008 and 2018.

# %%
mean_value = zipcode_grp.value.mean()
mean_value = mean_value.sort_values(ascending=False).head(10)

# %%
mean_value.plot.bar(color='pink')
plt.title('Top 10 Zipcodes  \n Highest Mean Value 2008-2018')
plt.ylabel('Value in Millions of Dollars ($)')
plt.show()
plt.savefig('Zipcodes')

# %% [markdown]
# Let's find our zipcode with the highest mean value.

# %%
melted_df.loc[melted_df['Zipcode']=='6840']
# Out:
#            Zipcode     Metro  SizeRank  ROI_5yr  ROI_3yr      value
# Date
# 2008-01-01    6840  Stamford      5941  -0.0012  -0.0764  1746000.0
# 2008-02-01    6840  Stamford      5941  -0.0012  -0.0764  1736100.0
# 2008-03-01    6840  Stamford      5941  -0.0012  -0.0764  1729800.0
# 2008-04-01    6840  Stamford      5941  -0.0012  -0.0764  1728700.0
# 2008-05-01    6840  Stamford      5941  -0.0012  -0.0764  1727600.0
# ...            ...       ...       ...      ...      ...        ...
# 2017-12-01    6840  Stamford      5941  -0.0012  -0.0764  1355500.0
# 2018-01-01    6840  Stamford      5941  -0.0012  -0.0764  1361600.0
# 2018-02-01    6840  Stamford      5941  -0.0012  -0.0764  1374500.0
# 2018-03-01    6840  Stamford      5941  -0.0012  -0.0764  1381400.0
# 2018-04-01    6840  Stamford      5941  -0.0012  -0.0764  1379900.0
#
# [124 rows x 6 columns]

# %% [markdown]
# Second highest mean value:

# %%
melted_df.loc[melted_df['Zipcode']=='6820']
# Out:
#            Zipcode     Metro  SizeRank  ROI_5yr  ROI_3yr      value
# Date
# 2008-01-01    6820  Stamford      6037   0.1149   0.0045  1401500.0
# 2008-02-01    6820  Stamford      6037   0.1149   0.0045  1399200.0
# 2008-03-01    6820  Stamford      6037   0.1149   0.0045  1395800.0
# 2008-04-01    6820  Stamford      6037   0.1149   0.0045  1392500.0
# 2008-05-01    6820  Stamford      6037   0.1149   0.0045  1391200.0
# ...            ...       ...       ...      ...      ...        ...
# 2017-12-01    6820  Stamford      6037   0.1149   0.0045  1375600.0
# 2018-01-01    6820  Stamford      6037   0.1149   0.0045  1374700.0
# 2018-02-01    6820  Stamford      6037   0.1149   0.0045  1379100.0
# 2018-03-01    6820  Stamford      6037   0.1149   0.0045  1385800.0
# 2018-04-01    6820  Stamford      6037   0.1149   0.0045  1388100.0
#
# [124 rows x 6 columns]

# %%
melted_df.value.describe()
# Out:
# count    1.537600e+04
# mean     2.802331e+05
# std      1.840456e+05
# min      8.010000e+04
# 25%      1.838000e+05
# 50%      2.419000e+05
# 75%      3.145250e+05
# max      1.746000e+06
# Name: value, dtype: float64

# %% [markdown]
# Let's find our Zipcode with the highest all time value.

# %%
melted_df.loc[melted_df['value']== 1746000]
# Out:
#            Zipcode     Metro  SizeRank  ROI_5yr  ROI_3yr      value
# Date
# 2008-01-01    6840  Stamford      5941  -0.0012  -0.0764  1746000.0

# %% [markdown]
# And now the Zipcode with the lowest all time value.

# %%
melted_df.loc[melted_df['value']== 80100]
# Out:
#            Zipcode      Metro  SizeRank  ROI_5yr  ROI_3yr    value
# Date
# 2015-04-01    6706  New Haven      7317   0.0274   0.3196  80100.0

# %% [markdown]
# Up next we will look into ROI. I have included a 5 year and a 3 year ROI. I will look into the top 10 percentile for each ratio and will select our "best zipcodes" from there.

# %% [markdown]
# * ### ROI 5 year

# %%
melted_df['ROI_5yr'].describe()
# Out:
# count    15376.000000
# mean         0.098785
# std          0.076585
# min         -0.081200
# 25%          0.051025
# 50%          0.090000
# 75%          0.130150
# max          0.415800
# Name: ROI_5yr, dtype: float64

# %%
ninety_perc_ROI_5yr = melted_df['ROI_5yr'].quantile(q=0.90)
top_10_perc = melted_df.loc[melted_df['ROI_5yr']>=ninety_perc_ROI_5yr]

# %%
top_10_perc.head(13)
# Out:
#            Zipcode       Metro  SizeRank  ROI_5yr  ROI_3yr     value
# Date
# 2008-01-01    6810    Stamford       685   0.2219   0.1839  321900.0
# 2008-01-01    6606    Stamford      1332   0.3202   0.2165  252300.0
# 2008-01-01    6513   New Haven      2301   0.2725   0.1802  187600.0
# 2008-01-01    6604    Stamford      3778   0.3141   0.3166  274700.0
# 2008-01-01    6610    Stamford      4717   0.2999   0.3111  216600.0
# 2008-01-01    6069  Torrington     12310   0.2366   0.2412  436300.0
# 2008-01-01    6757  Torrington     13018   0.1872   0.1357  392700.0
# 2008-01-01    6039  Torrington     13065   0.3212   0.1861  535900.0
# 2008-01-01    6235   Worcester     13214   0.2034   0.1916  228700.0
# 2008-01-01    6763  Torrington     13465   0.1846   0.1117  348900.0
# 2008-01-01    6058  Torrington     13564   0.4158   0.1849  350900.0
# 2008-01-01    6068  Torrington     13646   0.2264   0.2487  511000.0
# 2008-01-01    6793  Torrington     14356   0.2023   0.1628  729100.0

# %% [markdown]
# * ### ROI 3 year

# %%
melted_df.ROI_3yr.describe()
# Out:
# count    15376.000000
# mean         0.090385
# std          0.073129
# min         -0.076400
# 25%          0.044225
# 50%          0.084900
# 75%          0.120900
# max          0.319600
# Name: ROI_3yr, dtype: float64

# %%
ninety_perc_ROI_3yr = melted_df['ROI_3yr'].quantile(q=0.90)
top_10_perc_3yr = melted_df.loc[melted_df['ROI_3yr']>=ninety_perc_ROI_3yr]

# %%
top_10_perc_3yr.info()
top_10_perc_3yr.head(13)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1612 entries, 2008-01-01 to 2018-04-01
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Zipcode   1612 non-null   object
#  1   Metro     1612 non-null   object
#  2   SizeRank  1612 non-null   int64
#  3   ROI_5yr   1612 non-null   float64
#  4   ROI_3yr   1612 non-null   float64
#  5   value     1612 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 88.2+ KB
#            Zipcode       Metro  SizeRank  ROI_5yr  ROI_3yr     value
# Date
# 2008-01-01    6606    Stamford      1332   0.3202   0.2165  252300.0
# 2008-01-01    6705   New Haven      3696   0.0056   0.1964  152500.0
# 2008-01-01    6604    Stamford      3778   0.3141   0.3166  274700.0
# 2008-01-01    6610    Stamford      4717   0.2999   0.3111  216600.0
# 2008-01-01    6351  New London      6591   0.1183   0.2234  217300.0
# 2008-01-01    6706   New Haven      7317   0.0274   0.3196  152200.0
# 2008-01-01    6359  New London     10786   0.1761   0.2189  282100.0
# 2008-01-01    6069  Torrington     12310   0.2366   0.2412  436300.0
# 2008-01-01    6330  New London     12817   0.1107   0.2078  232100.0
# 2008-01-01    6039  Torrington     13065   0.3212   0.1861  535900.0
# 2008-01-01    6235   Worcester     13214   0.2034   0.1916  228700.0
# 2008-01-01    6068  Torrington     13646   0.2264   0.2487  511000.0
# 2008-01-01    6796  Torrington     14552   0.1274   0.2028  532000.0

# %%
df = top_10_perc_3yr.drop(columns=['Metro', 'SizeRank'])
df.head()
# Out:
#            Zipcode  ROI_5yr  ROI_3yr     value
# Date
# 2008-01-01    6606   0.3202   0.2165  252300.0
# 2008-01-01    6705   0.0056   0.1964  152500.0
# 2008-01-01    6604   0.3141   0.3166  274700.0
# 2008-01-01    6610   0.2999   0.3111  216600.0
# 2008-01-01    6351   0.1183   0.2234  217300.0

# %% [markdown]
# Our final dataframe includes 13 zipcodes.

# %%
px.line(df, color='Zipcode')
# Out:
# <div>                            <div id="c8b05726-46b4-48c3-ad63-216c74785439" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8b05726-46b4-48c3-ad63-216c74785439")) {                    Plotly.newPlot(                        "c8b05726-46b4-48c3-ad63-216c74785439",                        [{"hovertemplate": "Zipcode=6606<br>variable=ROI_5yr<br>Date=%{x}<br>_value=%{y}<extra></extra>", "legendgroup": "6606", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "6606", "showlegend": true, "type": "scattergl", "x": ["2008-01-01T00:00:00", "2008-02-01T00:00:00", "2008-03-01T00:00:00", "2008-04-01T00:00:00", "2008-05-01T00:00:00", "2008-06-01T00:00:00", "2008-07-01T00:00:00", "2008-08-01T00:00:00", "2008-09-01T00:00:00", "2008-10-01T00:00:00", "2008-11-01T00:00:00", "2008-12-01T00:00:00", "2009-01-01T00:00:00", "2009-02-01T00:00:00", "2009-03-01T00:00:00", "2009-04-01T00:00:00", "2009-05-01T00:00:00", "2009-06-01T00:00:00", "2009-07-01T00:00:00", "2009-08-01T00:00:00", "2009-09-01T00:00:00", "2009-10-01T00:00:00", "2009-11-01T00:00:00", "2009-12-01T00:00:00", "2010-01-01T00:00:00", "2010-02-01T00:00:00", "2010-03-01T00:00:00", "2010-04-01T00:00:00", "2010-05-01T00:00:00", "2010-06-01T00:00:00", "2010-07-01T00:00:00", "2010-08-01T00:00:00", "2010-09-01T00:00:00", "2010-10-01T00:00:00", "2010-11-01T00:00:00", "2010-12-01T00:00:00", "2011-01-01T00:00:00", "2011-02-01T00:00:00", "2011-03-01T00:00:00", "2011-04-01T00:00:00", "2011-05-01T00:00:00", "2011-06-01T00:00:00", "2011-07-01T00:00:00", "2011-08-01T00:00:00", "2011-09-01T00:00:00", "2011-10-01T00:00:00", "2011-11-01T00:00:00", "2011-12-01T00:00:00", "2012-01-01T00:00:00", "2012-02-01T00:00:00", "2012-03-01T00:00:00", "2012-04-01T00:00:00", "2012-05-01T00:00:00", "2012-06-01T00:00:00", "2012-07-01T00:00:00", "2012-08-01T00:00:00", "2012-09-01T00:00:00", "2012-10-01T00:00:00", "2012-11-01T00:00:00", "2012-12-01T00:00:00", "2013-01-01T00:00:00", "2013-02-01T00:00:00", "2013-03-01T00:00:00", "2013-04-01T00:00:00", "2013-05-01T00:00:00", "2013-06-01T00:00:00", "2013-07-01T00:00:00", "2013-08-01T00:00:00", "2013-09-01T00:00:00", "2013-10-01T00:00:00", "2013-11-01T00:00:00", "2013-12-01T00:00:00", "2014-01-01T00:00:00", "2014-02-01T00:00:00", "2014-03-01T00:00:00", "2014-04-01T00:00:00", "2014-05-01T00:00:00", "2014-06-01T00:00:00", "2014-07-01T00:00:00", "2014-08-01T00:00:00", "2014-09-01T00:00:00", "2014-10-01T00:00:00", "2014-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "2016-07-01T00:00:00", "2016-08-01T00:00:00", "2016-09-01T00:00:00", "2016-10-01T00:00:00", "2016-11-01T00:00:00", "2016-12-01T00:00:00", "2017-01-01T00:00:00", "2017-02-01T00:00:00", "2017-03-01T00:00:00", "2017-04-01T00:00:00", "2017-05-01T00:00:00", "2017-06-01T00:00:00", "2017-07-01T00:00:00", "2017-08-01T00:00:00", "2017-09-01T00:00:00", "2017-10-01T00:00:00", "2017-11-01T00:00:00", "2017-12-01T00:00:00", "2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00"], "xaxis": "x", "y": [0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.3202, 0.320 ...

# %%
# %store melted_df
# Out:
# Stored 'melted_df' (DataFrame)

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
## Analysis continues in Notebook_2_ARIMA_Modeling
